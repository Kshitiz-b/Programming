# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Dataset
dataset = [
    ['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
    ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
    ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
    ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
    ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']
]

# Convert the dataset into a one-hot encoded DataFrame
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %% [markdown]
# ### a. Find the frequent itemset from the dataset with support count = 4 and support count = 2.

# %%
frequent_itemsets_4 = apriori(df, min_support=4/len(df), use_colnames=True)
frequent_itemsets_2 = apriori(df, min_support=2/len(df), use_colnames=True)

print("Frequent Itemsets with Support Count = 4:")
print(frequent_itemsets_4)

print("\nFrequent Itemsets with Support Count = 2:")
print(frequent_itemsets_2)
# Out:
# Frequent Itemsets with Support Count = 4:
#    support              itemsets
# 0      0.8                (Eggs)
# 1      1.0        (Kidney Beans)
# 2      0.8  (Kidney Beans, Eggs)
#
# Frequent Itemsets with Support Count = 2:
#     support                                     itemsets
# 0       0.4                                       (Corn)
# 1       0.8                                       (Eggs)
# 2       1.0                               (Kidney Beans)
# 3       0.6                                       (Milk)
# 4       0.4                                     (Nutmeg)
# 5       0.6                                      (Onion)
# 6       0.6                                     (Yogurt)
# 7       0.4                         (Kidney Beans, Corn)
# 8       0.8                         (Kidney Beans, Eggs)
# 9       0.4                                 (Eggs, Milk)
# 10      0.4                               (Eggs, Nutmeg)
# 11      0.6                                (Onion, Eggs)
# 12      0.4                               (Yogurt, Eggs)
# 13      0.6                         (Kidney Beans, Milk)
# 14      0.4                       (Kidney Beans, Nutmeg)
# 15      0.6                        (Kidney Beans, Onion)
# 16      0.6                       (Kidney Beans, Yogurt)
# 17      0.4                               (Yogurt, Milk)
# 18      0.4                              (Onion, Nutmeg)
# 19      0.4                             (Yogurt, Nutmeg)
# 20      0.4                              (Onion, Yogurt)
# 21      0.4                   (Kidney Beans, Eggs, Milk)
# 22      0.4                 (Kidney Beans, Eggs, Nutmeg)
# 23      0.6                  (Kidney Beans, Onion, Eggs)
# 24      0.4                 (Kidney Beans, Yogurt, Eggs)
# 25      0.4                        (Onion, Eggs, Nutmeg)
# 26      0.4                       (Yogurt, Eggs, Nutmeg)
# 27      0.4                        (Onion, Yogurt, Eggs)
# 28      0.4                 (Kidney Beans, Yogurt, Milk)
# 29      0.4                (Kidney Beans, Onion, Nutmeg)
# 30      0.4               (Kidney Beans, Yogurt, Nutmeg)
# 31      0.4                (Kidney Beans, Onion, Yogurt)
# 32      0.4                      (Onion, Yogurt, Nutmeg)
# 33      0.4          (Kidney Beans, Onion, Eggs, Nutmeg)
# 34      0.4         (Kidney Beans, Yogurt, Eggs, Nutmeg)
# 35      0.4          (Kidney Beans, Onion, Yogurt, Eggs)
# 36      0.4                (Onion, Yogurt, Eggs, Nutmeg)
# 37      0.4        (Kidney Beans, Onion, Yogurt, Nutmeg)
# 38      0.4  (Eggs, Kidney Beans, Nutmeg, Onion, Yogurt)

# %% [markdown]
# ### b. Generate the association rules for support count 2 using the two methods ‘confidence’ and ‘lift’.

# %%
rules_confidence = association_rules(frequent_itemsets_2, metric="confidence", min_threshold=0.7)
rules_lift = association_rules(frequent_itemsets_2, metric="lift", min_threshold=1.0)

print("\nAssociation Rules (by Confidence):")
print(rules_confidence)

print("\nAssociation Rules (by Lift):")
print(rules_lift)
# Out:
# Association Rules (by Confidence):
#                 antecedents                          consequents  \
# 0                    (Corn)                       (Kidney Beans)
# 1            (Kidney Beans)                               (Eggs)
# 2                    (Eggs)                       (Kidney Beans)
# 3                  (Nutmeg)                               (Eggs)
# 4                   (Onion)                               (Eggs)
# ..                      ...                                  ...
# 99   (Kidney Beans, Nutmeg)                (Onion, Yogurt, Eggs)
# 100         (Onion, Nutmeg)         (Kidney Beans, Yogurt, Eggs)
# 101        (Yogurt, Nutmeg)          (Kidney Beans, Onion, Eggs)
# 102         (Onion, Yogurt)         (Kidney Beans, Eggs, Nutmeg)
# 103                (Nutmeg)  (Kidney Beans, Onion, Yogurt, Eggs)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                   0.4                 1.0      0.4         1.0  1.000000
# 1                   1.0                 0.8      0.8         0.8  1.000000
# 2                   0.8                 1.0      0.8         1.0  1.000000
# 3                   0.4                 0.8      0.4         1.0  1.250000
# 4                   0.6                 0.8      0.6         1.0  1.250000
# ..                  ...                 ...      ...         ...       ...
# 99                  0.4                 0.4      0.4         1.0  2.500000
# 100                 0.4                 0.4      0.4         1.0  2.500000
# 101                 0.4                 0.6      0.4         1.0  1.666667
# 102                 0.4                 0.4      0.4         1.0  2.500000
# 103                 0.4                 0.4      0.4         1.0  2.500000
#
#      leverage  conviction  zhangs_metric
# 0        0.00         inf       0.000000
# 1        0.00         1.0       0.000000
# 2        0.00         inf       0.000000
# 3        0.08         inf       0.333333
# 4        0.12         inf       0.500000
# ..        ...         ...            ...
# 99       0.24         inf       1.000000
# 100      0.24         inf       1.000000
# 101      0.16         inf       0.666667
# 102      0.24         inf       1.000000
# 103      0.24         inf       1.000000
#
# [104 rows x 10 columns]
#
# Association Rules (by Lift):
#         antecedents                            consequents  \
# 0    (Kidney Beans)                                 (Corn)
# 1            (Corn)                         (Kidney Beans)
# 2    (Kidney Beans)                                 (Eggs)
# 3            (Eggs)                         (Kidney Beans)
# 4            (Eggs)                               (Nutmeg)
# ..              ...                                    ...
# 183          (Eggs)  (Kidney Beans, Onion, Yogurt, Nutmeg)
# 184  (Kidney Beans)          (Onion, Yogurt, Eggs, Nutmeg)
# 185        (Nutmeg)    (Kidney Beans, Onion, Yogurt, Eggs)
# 186         (Onion)   (Kidney Beans, Yogurt, Eggs, Nutmeg)
# 187        (Yogurt)    (Kidney Beans, Onion, Eggs, Nutmeg)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                   1.0                 0.4      0.4    0.400000  1.000000
# 1                   0.4                 1.0      0.4    1.000000  1.000000
# 2                   1.0                 0.8      0.8    0.800000  1.000000
# 3                   0.8                 1.0      0.8    1.000000  1.000000
# 4                   0.8                 0.4      0.4    0.500000  1.250000
# ..                  ...                 ...      ...         ...       ...
# 183                 0.8                 0.4      0.4    0.500000  1.250000
# 184                 1.0                 0.4      0.4    0.400000  1.000000
# 185                 0.4                 0.4      0.4    1.000000  2.500000
# 186                 0.6                 0.4      0.4    0.666667  1.666667
# 187                 0.6                 0.4      0.4    0.666667  1.666667
#
#      leverage  conviction  zhangs_metric
# 0        0.00         1.0            0.0
# 1        0.00         inf            0.0
# 2        0.00         1.0            0.0
# 3        0.00         inf            0.0
# 4        0.08         1.2            1.0
# ..        ...         ...            ...
# 183      0.08         1.2            1.0
# 184      0.00         1.0            0.0
# 185      0.24         inf            1.0
# 186      0.16         1.8            1.0
# 187      0.16         1.8            1.0
#
# [188 rows x 10 columns]
