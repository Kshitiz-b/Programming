# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten 
from tensorflow.keras.utils import to_categorical 
import matplotlib.pyplot as plt
# Kshitiz Bhargava 21BCE2067

# %%
# Load the MNIST dataset
(x_train, y_train), (X_test, y_test) = mnist.load_data()
# Normalize the input data
x_train = x_train.astype('float32') / 255
x_test = X_test.astype('float32') / 255
# Kshitiz Bhargava 21BCE2067

# %%
# Convert labels to one-hot encoding
y_train = to_categorical (y_train, 10)
y_test = to_categorical(y_test, 10)
# Kshitiz Bhargava 21BCE2067

# %%
# Build the feedforward neural network model
model = Sequential(
    [
        Flatten(input_shape=(28, 28)),  # Flatten the input image
        Dense(128, activation="relu"),  # First hidden layer with 128 neurons
        Dense(64, activation="relu"),  # Second hidden layer with 64 neurons
        Dense(10, activation="softmax"),  # Output layer with 10 neurons for 10 classes
    ]
)
# Kshitiz Bhargava 21BCE2067
# Out:
# /Users/kshitiz/Documents/GitHub/Programming/.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Kshitiz Bhargava 21BCE2067

# %%
# Train the model and capture the training history
history = model.fit(x_train, y_train, epochs=10, batch_size=32,validation_split=0.2)
# Kshitiz Bhargava 21BCE2067
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 888us/step - accuracy: 0.8659 - loss: 0.4674 - val_accuracy: 0.9579 - val_loss: 0.1360
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 867us/step - accuracy: 0.9659 - loss: 0.1112 - val_accuracy: 0.9635 - val_loss: 0.1150
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 848us/step - accuracy: 0.9767 - loss: 0.0762 - val_accuracy: 0.9707 - val_loss: 0.1021
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 856us/step - accuracy: 0.9823 - loss: 0.0584 - val_accuracy: 0.9714 - val_loss: 0.0996
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 869us/step - accuracy: 0.9861 - loss: 0.0428 - val_accuracy: 0.9711 - val_loss: 0.1117
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 866us/step - accuracy: 0.9889 - loss: 0.0337 - val_accuracy: 0.9732 - val_loss: 0.1022
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 897us/step - accuracy: 0.9902 - loss: 0.0294 - val_accuracy: 0.9759 - val_loss: 0.0947
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 881us/step - accuracy: 0.9918 - loss: 0.0257 - val_accuracy: 0.9749 - val_loss: 0.1067
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 882us/step - accuracy: 0.9938 - loss: 0.0187 - val_accuracy: 0.9740 - val_loss: 0.1198
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 868us/step - accuracy: 0.9938 - loss: 0.0176 - val_accuracy: 0.9728 - val_loss: 0.1243

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Kshitiz Bhargava 21BCE2067
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.9742 - loss: 0.1172
# Test accuracy: 0.9764999747276306

# %%
# Plot the accuracy graph
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Kshitiz Bhargava 21BCE2067\n\nTraining and Validation Accuracy\n')
plt.legend()
plt.show()
# Kshitiz Bhargava 21BCE2067
