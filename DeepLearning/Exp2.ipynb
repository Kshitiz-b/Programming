# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten 
from tensorflow.keras.utils import to_categorical 
import matplotlib.pyplot as plt
# Kshitiz Bhargava 21BCE2067

# %%
# Load the MNIST dataset
(x_train, y_train), (X_test, y_test) = mnist.load_data()
# Normalize the input data
x_train = x_train.astype('float32') / 255
x_test = X_test.astype('float32') / 255
# Kshitiz Bhargava 21BCE2067

# %%
# Convert labels to one-hot encoding
y_train = to_categorical (y_train, 10)
y_test = to_categorical(y_test, 10)
# Kshitiz Bhargava 21BCE2067

# %%
# Build the feedforward neural network model
model = Sequential(
    [
        Flatten(input_shape=(28, 28)),  # Flatten the input image
        Dense(128, activation="relu"),  # First hidden layer with 128 neurons
        Dense(64, activation="relu"),  # Second hidden layer with 64 neurons
        Dense(10, activation="softmax"),  # Output layer with 10 neurons for 10 classes
    ]
)
# Kshitiz Bhargava 21BCE2067
# Out:
# /Users/kshitiz/Documents/GitHub/Programming/.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Kshitiz Bhargava 21BCE2067

# %%
# Train the model and capture the training history
history = model.fit(x_train, y_train, epochs=10, batch_size=32,validation_split=0.2)
# Kshitiz Bhargava 21BCE2067
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 973us/step - accuracy: 0.8585 - loss: 0.4807 - val_accuracy: 0.9544 - val_loss: 0.1498
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 862us/step - accuracy: 0.9648 - loss: 0.1145 - val_accuracy: 0.9683 - val_loss: 0.1012
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 905us/step - accuracy: 0.9755 - loss: 0.0775 - val_accuracy: 0.9715 - val_loss: 0.0990
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 909us/step - accuracy: 0.9825 - loss: 0.0561 - val_accuracy: 0.9728 - val_loss: 0.0944
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 877us/step - accuracy: 0.9872 - loss: 0.0405 - val_accuracy: 0.9762 - val_loss: 0.0908
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9895 - loss: 0.0324 - val_accuracy: 0.9704 - val_loss: 0.1096
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - accuracy: 0.9911 - loss: 0.0275 - val_accuracy: 0.9754 - val_loss: 0.0931
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 868us/step - accuracy: 0.9931 - loss: 0.0204 - val_accuracy: 0.9749 - val_loss: 0.1041
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - accuracy: 0.9936 - loss: 0.0182 - val_accuracy: 0.9762 - val_loss: 0.0988
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 929us/step - accuracy: 0.9948 - loss: 0.0153 - val_accuracy: 0.9763 - val_loss: 0.1127

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Kshitiz Bhargava 21BCE2067
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.9711 - loss: 0.1154
# Test accuracy: 0.9758999943733215

# %%
# Plot the accuracy graph
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Kshitiz Bhargava 21BCE2067\n\nTraining and Validation Accuracy\n')
plt.legend()
plt.show()
# Kshitiz Bhargava 21BCE2067
